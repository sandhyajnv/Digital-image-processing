# %% [markdown]
# <a href="https://colab.research.google.com/github/sandhyajnv/Digital-image-processing/blob/main/DIP_assignment_3_Q2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import math 
import cv2
import os
import pandas as pd

# %%
from google.colab.patches import cv2_imshow

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
img = mpimg.imread('/content/drive/MyDrive/Images_HWS-20230225T091550Z-001/Images_HWS/DIP_gray_scales/Soldiers - Copy.tif')

# %%
img=img[:,:,0]
siz=img.shape
print(siz)
cv2_imshow(img)
# Out:
# (256, 256)
# <PIL.Image.Image image mode=L size=256x256 at 0x7F70AC565490>

# %%
gauss_noise=5*(np.random.randn(siz[0],siz[1]))

# %%
plt.imshow(gauss_noise,cmap="gray")

# %%
gn_img=img+gauss_noise

# %%
cv2_imshow(gn_img)
# Out:
# <PIL.Image.Image image mode=L size=256x256 at 0x7F70ABF4C9A0>

# %% [markdown]
# Q.2.1For Average filter of size 3*3 is good as other filters are loosing details of the image

# %%
k=1
for i in range(7):
  k=k+2
  kernel = np.ones((k,k),np.float32)/25
  dst = cv2.filter2D(gn_img,-1,kernel)
  plt.title("for Average filter of size {}".format(k))
  plt.imshow(dst,cmap="gray")
  plt.show()

# kernel = np.ones((5,5),np.float32)/25
# dst = cv2.filter2D(gn_img,-1,kernel)

# plt.imshow(dst,cmap="gray")

# %% [markdown]
# Q.2.2

# %%
k=0
for i in range(10):
  k=k+0.5
  new_image = cv2.GaussianBlur(gn_img,(5, 5),k)
  
  #plt.figure(figsize=(10,6))
  #plt.rcParams['figure.figsize'] = [10, 6]
  
  plt.title("for gaussain filter standard deviation {}".format(k))
  plt.imshow(new_image,cmap="gray")
  plt.show()

# %%
gn_img=np.float32(gn_img)

# %% [markdown]
# Q.2.3

# %%
k=1
for i in range(2):
  k=k+2
  blurred=cv2.medianBlur(gn_img,k)
  plt.title("for Median filter of size  {}".format(k))
  plt.imshow(new_image,cmap="gray")
  plt.show()

# %% [markdown]
# Q.2.4

# %%
# img = cv2.imread('messi5.jpg')
# gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img_gaussian = cv2.GaussianBlur(img,(3,3),0)

#canny
#img_canny = cv2.Canny(img,100,200)

#sobel
img_sobelx = cv2.Sobel(img_gaussian,cv2.CV_8U,1,0,ksize=5)
img_sobely = cv2.Sobel(img_gaussian,cv2.CV_8U,0,1,ksize=5)
img_sobel = img_sobelx + img_sobely


#prewitt
kernelx = np.array([[1,1,1],[0,0,0],[-1,-1,-1]])
kernely = np.array([[-1,0,1],[-1,0,1],[-1,0,1]])
img_prewittx = cv2.filter2D(img_gaussian, -1, kernelx)
img_prewitty = cv2.filter2D(img_gaussian, -1, kernely)

plt.title("original image")
plt.imshow( img,cmap="gray")
plt.show()
plt.title("Sobel X")
plt.imshow( img_sobelx,cmap="gray")
plt.show()
plt.title("Sobel Y")
plt.imshow(img_sobely,cmap="gray")
plt.show()
plt.title("Sobel")
plt.imshow(img_sobel,cmap="gray")
plt.show()
plt.title("Prewitt X")
plt.imshow(img_prewittx,cmap="gray")
plt.show()
plt.title("Prewitt Y")
plt.imshow(img_prewitty,cmap="gray")
plt.show()
plt.title("Prewitt")
plt.imshow(img_prewittx + img_prewitty,cmap='gray')
plt.show()
